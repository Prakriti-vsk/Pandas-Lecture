# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
var = sns.load_dataset('penguins')

# %%
var
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
j=pd.DataFrame({'Roll':[1,2,None,4,5,None,3,10,None]})
j
# Out:
#    Roll
# 0   1.0
# 1   2.0
# 2   NaN
# 3   4.0
# 4   5.0
# 5   NaN
# 6   3.0
# 7  10.0
# 8   NaN

# %%
j.interpolate()
# Out:
#    Roll
# 0   1.0
# 1   2.0
# 2   3.0
# 3   4.0
# 4   5.0
# 5   4.0
# 6   3.0
# 7  10.0
# 8  10.0

# %%
j
# Out:
#    Roll
# 0   1.0
# 1   2.0
# 2   NaN
# 3   4.0
# 4   5.0
# 5   NaN
# 6   3.0
# 7  10.0
# 8   NaN

# %%
y=pd.DataFrame({'Roll':[1,2,3,4,None],
               'Name':['aman','sachin','amit','kajal',None]})
y
# Out:
#    Roll    Name
# 0   1.0    aman
# 1   2.0  sachin
# 2   3.0    amit
# 3   4.0   kajal
# 4   NaN    None

# %%
y.notna()
# Out:
#     Roll   Name
# 0   True   True
# 1   True   True
# 2   True   True
# 3   True   True
# 4  False  False

# %%
y.notnull()
# Out:
#     Roll   Name
# 0   True   True
# 1   True   True
# 2   True   True
# 3   True   True
# 4  False  False

# %%
y.pad()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1780\3704877376.py:1: FutureWarning: DataFrame.pad/Series.pad is deprecated. Use DataFrame.ffill/Series.ffill instead
#   y.pad()
#    Roll    Name
# 0   1.0    aman
# 1   2.0  sachin
# 2   3.0    amit
# 3   4.0   kajal
# 4   4.0   kajal

# %%
j
# Out:
#    Roll
# 0   1.0
# 1   2.0
# 2   NaN
# 3   4.0
# 4   5.0
# 5   NaN
# 6   3.0
# 7  10.0
# 8   NaN

# %%
j.pad()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1780\2215419772.py:1: FutureWarning: DataFrame.pad/Series.pad is deprecated. Use DataFrame.ffill/Series.ffill instead
#   j.pad()
#    Roll
# 0   1.0
# 1   2.0
# 2   2.0
# 3   4.0
# 4   5.0
# 5   5.0
# 6   3.0
# 7  10.0
# 8  10.0

# %%
var
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
var['species'].replace('Gentoo','How')
# Out:
# 0      Adelie
# 1      Adelie
# 2      Adelie
# 3      Adelie
# 4      Adelie
#         ...
# 339       How
# 340       How
# 341       How
# 342       How
# 343       How
# Name: species, Length: 344, dtype: object

# %%
z=var.set_index(['species','island'])

# %%
z
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# species island
# Adelie  Torgersen            39.1           18.7              181.0
#         Torgersen            39.5           17.4              186.0
#         Torgersen            40.3           18.0              195.0
#         Torgersen             NaN            NaN                NaN
#         Torgersen            36.7           19.3              193.0
# ...                           ...            ...                ...
# Gentoo  Biscoe                NaN            NaN                NaN
#         Biscoe               46.8           14.3              215.0
#         Biscoe               50.4           15.7              222.0
#         Biscoe               45.2           14.8              212.0
#         Biscoe               49.9           16.1              213.0
#
#                    body_mass_g     sex
# species island
# Adelie  Torgersen       3750.0    Male
# ...

# %%
z
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# species island
# Adelie  Torgersen            39.1           18.7              181.0
#         Torgersen            39.5           17.4              186.0
#         Torgersen            40.3           18.0              195.0
#         Torgersen             NaN            NaN                NaN
#         Torgersen            36.7           19.3              193.0
# ...                           ...            ...                ...
# Gentoo  Biscoe                NaN            NaN                NaN
#         Biscoe               46.8           14.3              215.0
#         Biscoe               50.4           15.7              222.0
#         Biscoe               45.2           14.8              212.0
#         Biscoe               49.9           16.1              213.0
#
#                    body_mass_g     sex
# species island
# Adelie  Torgersen       3750.0    Male
# ...

# %%
v=z.droplevel('island')

# %%
v
# Out:
#          bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g     sex
# species
# Adelie             39.1           18.7              181.0       3750.0    Male
# Adelie             39.5           17.4              186.0       3800.0  Female
# Adelie             40.3           18.0              195.0       3250.0  Female
# Adelie              NaN            NaN                NaN          NaN     NaN
# Adelie             36.7           19.3              193.0       3450.0  Female
# ...                 ...            ...                ...          ...     ...
# Gentoo              NaN            NaN                NaN          NaN     NaN
# Gentoo             46.8           14.3              215.0       4850.0  Female
# Gentoo             50.4           15.7              222.0       5750.0    Male
# Gentoo             45.2           14.8              212.0       5200.0  Female
# Gentoo             49.9           16.1              213.0       5400.0    Male
#
# ...

# %%
v.to_excel('mahindra.xlsx')

# %%
# !pip install openpyxl

# %%
from matplotlib.colors import LogNorm

X, Y = np.meshgrid(np.linspace(-3, 3, 128), np.linspace(-3, 3, 128))
Z = (1 - X/2 + X**5 + Y**3) * np.exp(-X**2 - Y**2)

fig, axs = plt.subplots(2, 2, layout='constrained')
pc = axs[0, 0].pcolormesh(X, Y, Z, vmin=-1, vmax=1, cmap='RdBu_r')
fig.colorbar(pc, ax=axs[0, 0])
axs[0, 0].set_title('pcolormesh()')

co = axs[0, 1].contourf(X, Y, Z, levels=np.linspace(-1.25, 1.25, 11))
fig.colorbar(co, ax=axs[0, 1])
axs[0, 1].set_title('contourf()')

pc = axs[1, 0].imshow(Z**2 * 100, cmap='plasma', norm=LogNorm(vmin=0.01, vmax=100))
fig.colorbar(pc, ax=axs[1, 0], extend='both')
axs[1, 0].set_title('imshow() with LogNorm()')

pc = axs[1, 0].imshow(Z**2 * 100, cmap='plasma', norm=LogNorm(vmin=0.01, vmax=100))
fig.colorbar(pc, ax=axs[1, 1], extend='both')
axs[1, 0].set_title('scatter()')
plt.show()
